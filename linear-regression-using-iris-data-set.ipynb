# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
iris = pd.read_csv("../input/iris-flower-dataset/IRIS.csv")
iris.head()

# %%
iris.shape

# %%
#extract data with sepal width > 4
iris[iris['sepal_width']>4]

# %%
#extractdata with petal_width >1
iris[iris['petal_width']>1]

# %%
#extractdata with petal_width >2
iris[iris['petal_width']>2]

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#See the relationship between Sepal length and petal length using visualization
sns.scatterplot(x = 'sepal_length',  y = "petal_length", data = iris)
plt.show()

# %%
# Color the species with hue parameter in seaborn
sns.scatterplot(x = 'sepal_length',  y = "petal_length", data = iris, hue = 'species')
plt.show()

# %%
#LINEAR REGRESSION MODEL BUILDING
#SEE HOW SEPAL LENGTH CHANGES W.R.T SEPAL WIDTH

# %%
#Create y variable (dependent variable)
y = iris[['sepal_length']]
y

# %%
#create x varaible (independent variable)
x = iris[['sepal_width']]
x

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test =train_test_split(x,y, test_size = 0.3)

# %%
x_train.head(),x_test.head(),y_train.head(),y_test.head()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)

# %%
y_pred = lr.predict(x_test)
y_pred

# %%
y_test.head(), y_pred[0:5]

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)

# %%
#Model - 2
y = iris[['sepal_length']] #Target variable

# %%
x = iris[['sepal_length','petal_width','petal_length']] #Independent variables

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.3) #Split the dataset

# %%
lr2 = LinearRegression()

# %%
lr2.fit(x_train,y_train) #Fit the model on training sets

# %%
y_pred =lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred) #Model 2 is better than better than model 1
